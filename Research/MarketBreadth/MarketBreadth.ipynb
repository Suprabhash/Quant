# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams['axes.grid'] = False
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})

# %%
from Strategies.MarketBreadth.MarketBreadth import MarketBreadth
from Metrics.Metrics import SharpeRatio
from Utils.add_features import max_over_lookback, min_over_lookback, sma
from Strategies.MarketBreadth.config import x
import pandas as pd

# %%
strat = MarketBreadth()
strat.get_data(".NSEI", "D")

# %%
_, ec, _ = strat.do_backtest(SharpeRatio, [x, x, 50, 30, 250, 60, 1000, 500], allocation = 1, interest_rate = 6,  plot=True, save_plot_to=None)

# %% [markdown]
# Printing Features

# %%
import pickle
with open(f'Test.pkl','rb') as file:
    data = pickle.load(file)
data.set_index("Datetime", inplace=True)

# %%
data.columns

# %%
for column in data.columns:
    if column.startswith("Fisher250"):
        data[["Close", column]].plot(secondary_y="Close")
