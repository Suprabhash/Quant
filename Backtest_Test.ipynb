# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams['axes.grid'] = False
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})

# %%
from Strategies.InverseFisher.InverseFisher import InverseFisher
from Metrics.Metrics import SharpeRatio
from Utils.add_features import max_over_lookback, min_over_lookback, sma
from Strategies.InverseFisher.config import x

# %%
strat = InverseFisher()
strat.get_data("^NSEI", "D")
params = [max_over_lookback, min_over_lookback, 50, 30, 60, -0.5, 0.5]
strat.data = strat.add_features(strat.data, [[param] for param in params])
_, ec = strat.do_backtest([max_over_lookback, min_over_lookback, 
            50, 30, 60, -0.5, 0.5], allocation = 1, interest_rate = 6,  plot=True, save_plot_to=None)
# Out:
# [*********************100%***********************]  1 of 1 completed
